# %%
import pandas as pd

pokemon_df = pd.read_csv('Pokemon.csv', sep=',')

display(pokemon_df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
a = pokemon_df.shape
a[1]
# Out:
# 13

# %%
pokemon_df.head(7)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# ...

# %%
pokemon_df.tail(2)
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 798  720  HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721           Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# ### Работа со столбцами

# %%
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
type_two = pokemon_df['Type 2']
type_two
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
# уникальные записи в столбце
type_two.unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
pokemon_df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
# самые популярные значения в столбце
pokemon_df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
# Найдите самые популярные записи в 'Type 1'
# Удалите столбец с индексами
# Примените метод describe() для самых первых 15 записей

print(pokemon_df['Type 1'].value_counts())
pokemon_df.drop('#', axis=1)
d=pokemon_df.head(15).describe()
d['Attack'].mean()
# Out:
# Water       112
# Normal       98
# Bug          69
# Grass        68
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64
# 58.22237146028914

# %% [markdown]
# ### Сортировка Данных

# %%
pokemon_df.sort_values(['HP', 'Attack', 'Defense', 'Sp. Atk'], ascending=
                      [False, False, False, False]).head(5)
# Out:
#        #       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja       Bug  Ghost    236    1      90       45       30
# 55    50    Diglett    Ground    NaN    265   10      55       25       35
# 139  129   Magikarp     Water    NaN    200   20      10       55       15
# 186  172      Pichu  Electric    NaN    205   20      40       15       35
# 230  213    Shuckle       Bug   Rock    505   20      10      230       10
# ..   ...        ...       ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola     Water    NaN    470  165      75       80       40
# 351  321    Wailord     Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet   Psychic    NaN    405  190      33       58       33
# 121  113    Chansey    Normal    NaN    450  250       5        5       35
# 261  242    Blissey    Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
top_five_strongest= pokemon_df.sort_values(['Total', 'Generation', 'HP', 'Speed'], ascending=
                      [False, False, True, False]).head(5)

# %% [markdown]
# ### Сохранение файлов на локальное устройство

# %%
top_five_strongest.to_csv('top_strongest.csv')
pd.read_csv('top_strongest.csv')
# Out:
#    Unnamed: 0    #                   Name   Type 1    Type 2  Total   HP  \
# 0         426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105
# 1         164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106
# 2         163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106
# 3         422  382    KyogrePrimal Kyogre    Water       NaN    770  100
# 4         424  383  GroudonPrimal Groudon   Ground      Fire    770  100
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     180      100      180      100    115           3       True
# 1     150       70      194      120    140           1       True
# 2     190      100      154      100    130           1       True
# 3     150       90      180      160     90           3       True
# 4     180      160      150       90     90           3       True

# %%
print(pokemon_df.sort_values('HP', ascending=True).head(10))

print(pokemon_df.sort_values('HP', ascending=False).tail(5))
# Out:
#        #       Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja       Bug  Ghost    236   1      90       45       30
# 55    50    Diglett    Ground    NaN    265  10      55       25       35
# 139  129   Magikarp     Water    NaN    200  20      10       55       15
# 186  172      Pichu  Electric    NaN    205  20      40       15       35
# 230  213    Shuckle       Bug   Rock    505  20      10      230       10
# 381  349     Feebas     Water    NaN    200  20      15       20       10
# 388  355    Duskull     Ghost    NaN    295  20      40       90       30
# 487  439   Mime Jr.   Psychic  Fairy    310  20      25       45       70
# 88    81  Magnemite  Electric  Steel    325  25      35       70       95
# 68    63       Abra   Psychic    NaN    310  25      20       15      105
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False
# 55        45     95           1      False
# ...

# %%
import numpy as np

university_ranking_df = pd.read_csv('World University Rankings 2023.csv', sep=',')


display(university_ranking_df.head(25))
display(university_ranking_df.tail(3))
display(university_ranking_df['Location'].value_counts().head(3))
print(university_ranking_df['Citations Score'].head(10).mean())
print(university_ranking_df.describe()['Citations Score'].mean())
# Out:
#    University Rank                     Name of University        Location  \
# 0                1                   University of Oxford  United Kingdom
# 1                2                     Harvard University   United States
# 2                3                University of Cambridge  United Kingdom
# 3                3                    Stanford University   United States
# 4                5  Massachusetts Institute of Technology   United States
# 5                6     California Institute of Technology   United States
# 6                7                   Princeton University   United States
# 7                8     University of California, Berkeley   United States
# 8                9                        Yale University   United States
# 9               10                Imperial College London  United Kingdom
# 10              11                    Columbia University   United States
# 11              11                             ETH Zurich     Switzerland
# ...

# %%
#1
transactions_data_df=pd.read_csv('transactions.csv', sep=';')
print(transactions_data_df)
print(transactions_data_df.shape)
#2
print(transactions_data_df.shape[0])
#3
print(transactions_data_df.shape[0])
#4
print(len(transactions_data_df.drop_duplicates()))
#5
print(transactions_data_df['Product'].mode()[0])
# Out:
#       Year  Month    ID Product  Amount   Price    Total    Cost
# 0   2012.0    1.0  t001      A1     7.0  2904.0  20328.0  1200.0
# 1   2012.0    1.0  t002      A2     2.0  1896.0   3792.0  1100.0
# 2   2012.0    2.0  t003      A1     5.0  2904.0  14520.0  1200.0
# 3   2012.0    2.0  t004      A4     1.0  8618.0   8618.0  4200.0
# 4   2012.0    2.0  t005      A5     3.0  5175.0  15525.0   500.0
# ..     ...    ...   ...     ...     ...     ...      ...     ...
# 58  2012.0   12.0  t059      _8     3.0  3760.0  11280.0   800.0
# 59  2012.0   12.0  t060      _3     4.0  1265.0   5060.0   700.0
# 60     NaN    NaN   NaN     NaN     NaN     NaN      NaN     NaN
# 61     NaN    NaN   NaN     NaN     NaN     NaN      NaN     NaN
# 62     NaN    NaN   NaN     NaN     NaN     NaN      NaN     NaN
#
# [63 rows x 8 columns]
# (63, 8)
# 63
# 63
# 61
# _5
